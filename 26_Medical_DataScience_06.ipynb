# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilaITOH/MedicalDataScience-exercises/blob/main/26_Medical_DataScience_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # メディカルデータサイエンス #6 畳み込みニューラルネットワーク (Convolutional Neural Networks: cNN)

# %% [markdown]
# ## 放射線医学、放射線技術学分野でのAIの適用例
# 1. 画像解析、診断支援
#
#     画像認識と分類: 異常な組織、腫瘍の検出、指摘
#
# 2. 画像品質向上
#
#     ノイズ低減、アーチファクト除去
#
# 3. 放射線治療の最適化
#
#     セグメンテーション支援、治療計画の選択

# %% [markdown]
# ### 画像認識
#
# 本講義では画像認識と分類を扱う
#
# - classification: 画像分類
# - detection: 物体検出
# - segmentation: セグメンテーション(輪郭検出)
#
# [人工知能による画像診断支援: 概念から応用まで](https://www.jstage.jst.go.jp/article/mii/37/2/37_11/_pdf)
#
# 植田大樹, “人工知能による画像診断支援: 概念から応用まで,” 医用画像情報学会雑誌, vol. 37, no. 2, pp. 11–20, 2020, doi: 10.11318/mii.37.11

# %% [markdown]
# ## これまで学んだ単純パーセプトロン
#
# 花弁やがくの幅、長さ(単位cm)という特徴量を入力することで、花の品種(species)を推論した
#
# ![1layerPerceptron.png](data:image/png;base64,...)

# %% [markdown]
# ## NNによる画像認識の基本的なアイデア
#
# 二次元画像を一次元に変形して画素値をNNに入力すれば、画像の画素値そのものを特徴量として利用できないだろうか？
#
# ![24188fe14fa9a8654bb73d710a78eec8_s.png](data:image/png;base64,...)
#
# [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# ### 予想される問題点
#
# 1. 特徴抽出の困難
#
#     画像は画像そのまま学習するには複雑すぎる。何らかの単純化が必要。
#     例えば輪郭だけで良い
#
# 2. 位置ずれによる認識不良
#
#     画面のどこにいても同じ物体は同じものと認識してほしい
#
#
#   そこで生物の視覚を模倣する。網膜と一次視覚野での情報処理に倣う。

# %% [markdown]
# ### 生物の網膜と一次視覚野での情報処理
#
# 網膜でコントラスト抽出した信号は視神経で一次視覚野に投影され、単純型細胞で輪郭抽出を行い、複雑型細胞で位置のずれを吸収する。
#
# ![020231df7e79f47a4ac0f1de728e147a_s.png](data:image/png;base64,...)
#
#  [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# #### 畳み込みによる輪郭抽出
#
# 畳み込み: 空間フィルタ
#
# Soble filter
#
# 問. 画像Aに対してフィルタFで空間フィルタ処理した時の画素値a(i=3,j=3)を求めよ。
#
# ![画像フィルタ-800x421.webp](data:image/webp;base64,...)
#
# [画像情報学　計算ドリル | 診療放射線技師国家試験　対策ノート](https://radiological.site/archives/%E7%94%BB%E5%83%8F%E6%83%85%E5%A0%B1%E5%AD%A6%E3%80%80%E8%A8%88%E7%AE%97%E3%83%89%E3%83%AA%E3%83%AB.html)

# %% [markdown]
# ##### 方向が異なる Sobel filter による異なる方向の輪郭抽出
#
#
# - Gx: 横線抽出
# - Gy: 縦線抽出
#
# 埋め込み画像は見づらいのでリンク先参照
#
# ![0_E5yCSJwVrjehNUPB copy.png](data:image/png;base64,...)
#
# それぞれのカーネルで畳み込み積分を実行した画像
#
# ![0_s37e9lRMAjB6cfmi.webp](data:image/webp;base64,...)
#
# [Edge Detection Techniques — Image Processing with OpenCV | by James Samuel | Medium](https://samuelabiodun.medium.com/edge-detection-techniques-image-processing-with-opencv-450e3ff8c601)

# %% [markdown]
# ### 位置ずれによる認識不良
#
# 位置Aにウサギがいる画像で学習したモデルは、位置Aに対応したニューロンがウサギの特徴を学習する。
#
# ![579148c986fc996905ce76ae6ceb32e5_s.png](data:image/png;base64,...)
#
# [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# このモデルに位置Bにウサギがいる画像Bを入力すると、画像Aで学習した人工ニューロンが発火しない。
#
# ![c562799da2b903a618b150a5d3e29c7a_s.png](data:image/png;base64,...)
#
# [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# #### プーリング層で特徴マップを圧縮、位置ずれに対応
#
# 画像サイズを縮小することで位置ずれがあっても同じ出力になるようにする。
#
# 最大値プーリング(Max pooling)
#
# 下図では4セルの最大値を代表値にすることで、特徴空間を1/4に縮小している、
#
# ![2d8e3e683f22c61de26c2a7f663ced35_m.png](data:image/png;base64,...)
#
# [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# ## ここまでのまとめ CNNの基本構成
#
# 入力された画像を畳み込み層で局所特徴量を抽出、プーリング層で位置普遍性を確保する。
#
# ![278972cfe79aa7537a36caa2ea6650e5_s.png](data:image/png;base64,...)
#
# [畳み込みニューラルネットワーク(CNN)をわかりやすく基本から実装まで解説 – <体験型>学習ブログ by zero to one](https://zero2one.jp/learningblog/cnn-for-beginners/)

# %% [markdown]
# # CNNによる手書き文字認識
#
# ラベルの付けられた手書き文字データセット MNIST data setを使う。
#
# 文字は28x28pxの画像
#
# ![mnist_plot-532x400.png](data:image/png;base64,...)
#
# [初心者のための畳み込みニューラルネットワーク（MNISTデータセット + Kerasを使ってCNNを構築）](https://www.codexa.net/cnn-mnist-keras-beginner/)

# %% [markdown]
# ## ランタイムの種類を変更
#
# ランタイムをCPUからGPUに変更する。
#
# GPU: Graphics Processing Unit
#
# 行列演算をCPUの数十倍の速度で実行できる。
#
# - ランタイム-> ランタイムの種類を変更
#
# ![Screenshot 2023-05-28 at 22.04.43_s.png](data:image/png;base64,...)
#
# - ハードウェアアクセラレータ
#
# CPU-> T4 GPU-> 保存
#
# ![t4.png](data:image/png;base64,...)

# %% [markdown]
# ## GPUランタイムに接続されていることを確認
# GPU Nameが 'Tesla T4'ならば’ok

# %%
# !nvidia-smi

# %% [markdown]
# ##データ分析の準備

# %% [markdown]
# ### ライブラリの読み込み(2025/6)
# Theanoバックエンドは開発中止されたため、tensorflow.kerasを使用する。

# %%
# tensorflow.kerasの必要なコンポーネントをインポート
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
# from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical  # Replaced np_utils with to_categor

from sklearn.datasets import fetch_openml
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### ラベル付き手書き数字画像データの読み込み
#
# ラベルの付けられた手書き数字画像データセット MNIST data setを使う。

# %%
# Scikit-learn経由でMNISTのオリジナルデータをダウンロードする。
# 手書き文字 70,000文字のラベル付きデータセット

mnist_X, mnist_y = fetch_openml('mnist_784', version=1, data_home=".", return_X_y=True)

#x_all = mnist_X.astype(np.float32) / 255
#y_all = mnist_y.astype(np.int32)
# 説明変数と目的変数に切り分ける
# X, y = mnist['data'], mnist['target']

# %% [markdown]
# #### 説明変数(数字画像)と目的変数(ラベル)のサイズとデータ型、データ形式を確認

# %%
# numpyのshape関数を使ってXのサイズとデータ形、データ形式を確認
print(mnist_X.shape)
print(mnist_X.dtypes)
print(type(mnist_X).__module__)
print(mnist_y.shape)
print(mnist_y.dtypes)
print(type(mnist_y).__module__)
#print('mnist_Xはnparray?' );
#print(type(mnist_X).__module__ == np.__name__)
#print(type(mnist_X).__module__)

# %% [markdown]
# #### 手書き数字画像を一つ見てみる
#
# まずは数字のまま配列として見る

# %%
# Xの53230番目のデータをtest_numberへ切り出す
test_number = mnist_X.loc[53230,:]

# reshape関数を使って784を28x28へ変換する
#test_number_image = test_number.reshape(28,28) #dataframe objectのままではreshapedできない　'DataFrame' object has no attribute 'reshape'
test_number_image = test_number.values.reshape(28,28)

# pandasのカラム表示の設定を変更
pd.options.display.max_columns = 28

# Numpy配列からPandasのデータフレームへ変換
number_matrix = pd.DataFrame(test_number_image)

# number_matrixの表示
number_matrix

# %% [markdown]
# #### 手書き文字画像データを画像化して表示する

# %%
# imshowを使って表示test_number_image（Numpy配列）を画像で表示
# %matplotlib inline

plt.imshow(test_number_image, cmap = matplotlib.cm.binary,
           interpolation='nearest')
plt.show()

# %% [markdown]
# #### ラベル(教師データ)を確認
#
# 正解が数字で記入されている

# %%
# 53230番目のYの値を出力
print(mnist_y[53230])

# %% [markdown]
# ### 前処理
#
# 単純パーセプトロンやDNNでIrisを分類した時と同様、データの前処理を行う。

# %% [markdown]
# #### データの分割
#
#
# トレーニングデータとテストデータに分割する
#
# - X_train: トレーニング用データ 60,000
# - X_test: テスト用データ 10,000
# - y_tarain: トレーニング用正解ラベル 60,000
# - y_test: テスト用正解ラベル 10,000

# %%
# 訓練データとテストデータを切り分ける
X_train, X_test, y_train, y_test = mnist_X.loc[:59999], mnist_X.loc[60000:], mnist_y[:60000], mnist_y[60000:]
y_test_backup = y_test

# 両方のサイズを確認
print(X_train.shape)
print(X_test.shape)

# %% [markdown]
# #### リサイズ

# %%
# 28x28x1のサイズへ変換する
X_train = X_train.values.reshape(X_train.shape[0], 28, 28,1)
X_test = X_test.values.reshape(X_test.shape[0], 28, 28,1)

# %% [markdown]
# #### 濃度値のスケーリング

# %%
# データタイプをfloat32へ変換
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# 正規化（ピクセルの最大値は255）
X_train /= 255
X_test /= 255

# %% [markdown]
# #### 前処理 ターゲットを1hot形式に変換する
#
# 出力層で1つのみビットが立つ形にする

# %%
# ターゲットとなるyを1hot形式に変換
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# y_testの1を表示
y_test[1]

# %% [markdown]
# ### ニューラルネットワークの作成

# %%
# モデルの宣言
model = Sequential()

# 先に作成したmodelへレイヤーを追加
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1))) #3x3の畳み込み
model.add(MaxPooling2D(pool_size=(2, 2))) #2x2へプーリング
model.add(Dropout(0.25)) #ドロップアウト
model.add(Flatten()) #ベクトル化
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax')) #出力

# Learnig Processの設定
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %% [markdown]
# #### 構築したモデルの確認
#
# 表形式で確認

# %%
# 構築したモデルの確認
print(model.summary())

# %% [markdown]
# #### フローチャート形式で確認

# %%
# モデルの可視化
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    show_shapes=True,
)

# %% [markdown]
# #### modelの模式図
#
# input - 畳み込み - プーリング - Dropout - flatton(5408node) - 128node - output(1hot)
#
# ![Screenshot 2023-05-29 at 2.14.39_m.png](data:image/png;base64,...)

# %% [markdown]
# ## 学習
#
# トレーニングデータによる予測モデル学習

# %%
# モデルの訓練（エポック １０）
# 注意 - CPUランタイムで実行すると、10〜15分程度かかります
# model.fit(X_train, y_train, epochs=10)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)

# %% [markdown]
# ## 評価
#
# テストデータによる推論を行い、精度評価

# %%
# テストデータを使ってモデルの評価
loss_and_metrics = model.evaluate(X_test, y_test, batch_size=128)
print(loss_and_metrics)

# %%
print(X_test.shape)

# %%
# X_testを使って予測を行う
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
x = list(predictions)
y = list(y_test_backup)
results = pd.DataFrame({'Actual': y, 'Predictions': x})
results[1:10]

# %% [markdown]
# #### 難しい例を確認する

# %%
# Xの53230番目のデータをtest_numberへ切り出す
test_number = X_test[8,:]
print(test_number.shape)
test_number_image = np.squeeze(test_number)

# pandasのカラム表示の設定を変更
pd.options.display.max_columns = 28

# Numpy配列からPandasのデータフレームへ変換
number_matrix = pd.DataFrame(test_number_image)

# number_matrixの表示
number_matrix

# %%
# imshowを使って表示test_number_image（Numpy配列）を画像で表示
# %matplotlib inline

plt.imshow(test_number_image, cmap = matplotlib.cm.binary,
           interpolation='nearest')
plt.show()

# %% [markdown]
# ## 学習過程の表示
#
# 学習を繰り返すほど損失関数が減少している

# %%
#ニューラルネットワークの学習過程を可視化してみよう – 株式会社ライトコード
#https://rightcode.co.jp/blog/information-technology/neural-network-learning-visualization
metrics = ['loss', 'accuracy']  # 使用する評価関数を指定

plt.figure(figsize=(10, 5))  # グラフを表示するスペースを用意

for i in range(len(metrics)):

    metric = metrics[i]

    plt.subplot(1, 2, i+1)  # figureを1×2のスペースに分け、i+1番目のスペースを使う
    plt.title(metric)  # グラフのタイトルを表示

    plt_train = history.history[metric]  # historyから訓練データの評価を取り出す
    plt_test = history.history['val_' + metric]  # historyからテストデータの評価を取り出す

    plt.plot(plt_train, label='training')  # 訓練データの評価をグラフにプロット
    plt.plot(plt_test, label='test')  # テストデータの評価をグラフにプロット
    plt.legend()  # ラベルの表示

plt.show()  # グラフの表示

# %% [markdown]
# ## Conv2Dの畳み込み積分のカーネルを確認
#
# 3x3のカーネルが32個ある
#
# cNNは、どんなカーネルを学習したのだろうか？

# %%
weights = model.get_layer("conv2d").get_weights()[0]
weights.shape

# %% [markdown]
# ### カーネルを表示する
#
# 0番目のカーネルを可視化
#
# - 数列表現
# - 画像化

# %%
w = weights[:, :, :, 0].copy()
m = w.min()
M = w.max()
w = (w-m)/(M-m)
plt.imshow(w, cmap = "gray")
print(w)

# %% [markdown]
# ### 全てのカーネルを画像で表示
#
# エッジ検出するカーネルが複数見られる

# %%
# 畳み込みニューラルネットワークの畳み込み層の重みを可視化する方法 | NHN テコラス Tech Blog | AWS、機械学習、IoTなどの技術ブログ
# https://techblog.nhn-techorus.com/archives/8813
from PIL import Image
result = Image.new("L", (3*8+(8-1), 3*8+(8-1)))
w_s = np.squeeze(weights) # サイズ1の次元を削除
for i in range(32):
    w= w_s[:, :, i].copy()
    M = w.max()
    m = w.min()
    w = (w-m)/(M-m)
    w *= 255
    img = Image.fromarray(w.astype("uint8"), mode = "L")
    result.paste(img, (3*(i%8) + (i%8), 3*(i//8) + (i//8)))
plt.imshow(result, cmap = "gray")

# %% [markdown]
# ## 次回使用教材
#
# 次回は胸部と腹部の放射線画像を分類するモデルを学びます
#
# >Lakhani, P., Gray, D. L., Pett, C. R., Nagy, P. & Shih, G. Hello World Deep Learning in Medical Imaging. J Digit Imaging 31, 2018; 283-289, doi: 10.1007/s10278-018-0079-6
#
# [Hello World Deep Learning in Medical Imaging](https://link.springer.com/article/10.1007/s10278-018-0079-6)
